# %% [markdown]
# <a href="https://colab.research.google.com/github/johnryantaylor/QCES/blob/main/Project1_numerical_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1: Diffusion equation

# %% [markdown]
# In this project we will use several methods to solve the diffusion equation:
#
# $$ \partial_t c = \kappa \partial_x^2 c $$
#
# This project consists of two notebooks. First, in this notebook, we will solve this equation using second order finite differences to approximate the $x$-derivatives, and we will use both the explict Euler and Crank-Nicolson timestepping methods.
#
# In the second notebook for this project, we will learn how to use Dedalus to solve the same problem using spectral methods.
#
# The objective for this notebook is learn about spatial discretization and to compare the stability, accuracy, and speed of the Explicit euler and Crank-Nicolson methods when applied to the diffusion equation.
#
# Student tasks are in [Section 2.1](#section2pt1) and [Section 2.2](#section2pt2).

# %% [markdown]
# Before we start, load in the required libraries

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sp
import scipy.sparse.linalg as spla
import time

# %% [markdown]
# Now, define two functions to timestep the diffusion equation. The code below timesteps the diffusion equation using the expicit Euler method. The function takes in a vector of discrete positions, `x`, discrete times, `t`, and the diffusivity, `kappa`. The vectors `x` and `t` dictate the discretization of the problem in space and time, and the grid spacing must be constant in space and time. The boundary conditions are $\partial_x c=0$ at the starting and ending points in `x`.

# %%
def EE(x, t, kappa,times = False):
# This function timesteps the diffusion equation with homogeneous Neumann boundary conditions
# using the explicit Euler and second order finite difference methods

    start_time = time.time()  # Start a timer

    # Infer the uniform grid spacing:
    dx = (x[-1] - x[0]) / (len(x) - 1); dt = (t[-1] - t[0]) / (len(t) - 1)

    # Set the number of gridpoints in x and t
    Nx = len(x); Nt = len(t)

    # Builds a coefficient matrix, such that M*c is the discrete version of d^2/dx^2(c)
    M = (np.diag(np.ones(Nx-1), -1) - 2*np.diag(np.ones(Nx), 0) + np.diag(np.ones(Nx-1), 1)) / dx**2

    # Turn M into a sparse matrix to save memory and improve speed
    M = sp.csr_matrix(M)

    # Create an empty sparse array to store the solution
    c = np.zeros((Nx, Nt))

    c[:, 0] = set_ics(x, kappa, 10)  # Set the initial condition

    for k in range(1, Nt):  # loop over the number of timesteps
      c[:,k] = c[:,k-1] + dt * kappa * M @ c[:,k-1]
      # Enforce the boundary conditions (no flux)
      c[0, k] = c[1, k]
      c[-1, k] = c[-2, k]

    end_time = time.time()  # Print the elapsed time

    #print(f"Explicit Euler method took {end_time - start_time:.2f} seconds")
    if times==True:
      return c, end_time - start_time
    else:
       return c

# %% [markdown]
# Similarly, the function below timesteps the diffusion equation with the Crank-Nicolson method

# %%
def CN(x, t, kappa, times = False):
# This function timesteps the diffusion equation with homogeneous Neumann boundary conditions
# using the explicit Euler and second order finite difference methods
    start_time = time.time()  # Start a timer

    # Infer the uniform grid spacing:
    dx = (x[-1] - x[0]) / (len(x) - 1); dt = (t[-1] - t[0]) / (len(t) - 1)

    # Set the number of gridpoints in x and t
    Nx = len(x); Nt = len(t)

    # build a coefficient matrix, such that M*c is the discrete version of d/dx(c)
    M = (np.diag(np.ones(Nx-1), -1) - 2*np.diag(np.ones(Nx), 0) + np.diag(np.ones(Nx-1), 1)) / dx**2

    # Turn M into a sparse matrix to save memory and improve speed:
    M = sp.csr_matrix(M)

    A = sp.eye(Nx) - 0.5 * dt * kappa * M  # This matrix appears on the LHS in the C-N scheme
    A_inv = spla.inv(A) # Calculate the inverse of A (this only needs to be done once)

    # Create an empty sparse array to store the solution
    c = np.zeros((Nx, Nt))

    c[:, 0] = set_ics(x, kappa, 10)  # Set the initial condition

    for k in range(1, Nt): # loop over the number of timesteps
        c[:, k] = A_inv @ (c[:, k-1] + 0.5 * dt * kappa * (M @ c[:, k-1]))
        # Enforce the boundary conditions
        c[0, k] = c[1, k]
        c[-1, k] = c[-2, k]

    end_time = time.time()  # Print the elapsed time

    #print(f"Crank-Nicolson method took {end_time - start_time:.2f} seconds")
    if times==True:
        return c, end_time - start_time
    else:
        return c

# %% [markdown]
# Next, create a function to set the initial conditions. The exact solution to the unbounded diffusion equation with a delta function initial condition is:
#
# $$\left(\frac{1}{4\pi\kappa t}\right)^{1/2}e^{-x^2/(4\kappa t)}$$
#
# The function below sets the initial condition by evaluating the exact solution at a given time. Note that it is important that we don't evaluate the exact solution at `t_ic=0` since this will return a delta function which will be undefined on our finite grid. The value of `t_ic` is set within the `EE` and `CN` functions.

# %%
# Function to set the initial condition from the exact solution at time t_start
def set_ics(x, kappa, t_ic):
    c_ic = (4*np.pi*kappa*t_ic)**(-0.5)*np.exp(-x**2 / (4*kappa*t_ic))
    # Enforce the boundary conditions
    c_ic[0] = c_ic[1]
    c_ic[-1] = c_ic[-2]
    return c_ic

# %% [markdown]
# Finally, define some parameters and the x and t vectors:

# %%
# Defining parameters
kappa = 0.001  # diffusivity

# Timestepping parameters
t_start = 0  # start time (note that this is not the same time used to evaluate the exact solution to set the ICs)
t_end = 10  # end time
Nt = 1000  # number of timesteps

# Size of the physical domain
x_start = -1
x_end = 1
Nx = 100

t = np.linspace(t_start, t_end, Nt)  # Create a vector of times
x = np.linspace(x_start, x_end, Nx)  # Create a vector for x

# %% [markdown]
# Run each method once:

# %%
# Run the simulations
c_EE = EE(x, t, kappa) # explicit Euler
c_CN = CN(x, t, kappa) # Crank-Nicolson
# Out:
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_dsolve/linsolve.py:603: SparseEfficiencyWarning: splu converted its input to CSC format
#   return splu(A).solve
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_matfuncs.py:76: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   Ainv = spsolve(A, I)

# %% [markdown]
# and finally, plot the results side-by-side

# %%
# Plot the results
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.pcolormesh(x, t, c_EE.T, shading='auto')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Explicit Euler')

plt.subplot(1, 2, 2)
plt.pcolormesh(x, t, c_CN.T, shading='auto')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Crank-Nicolson')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Student investigation

# %% [markdown]
# ### 2.1 Stability
# <a id='section2pt1'></a>
# The explicit Euler and Crank-Nicolson methods have very different stability properties. To explore this, try increasing Nx (decreasing the grid spacing, $\Delta x$) and/or increase the diffusivity, $\kappa$, and see how each method responds. How does the stability depend on `Nx`? Discuss your findings below (~1 paragraph)

# %%
def changetime (Nt,Nx,kappa, plot = True):

  t = np.linspace(t_start, t_end, Nt)  # Create a vector of times
  x = np.linspace(x_start, x_end, Nx)  # Create a vector for x

  c_EE = EE(x, t, kappa) # explicit Euler
  c_CN = CN(x, t, kappa) # Crank-Nicolson


  if plot ==True:
    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.pcolormesh(x, t, c_EE.T, shading='auto')
    plt.xlabel('x')
    plt.ylabel('t')
    plt.title('Explicit Euler')


    plt.subplot(1, 2, 2)
    plt.pcolormesh(x, t, c_CN.T, shading='auto')
    plt.xlabel('x')
    plt.ylabel('t')
    plt.title('Crank-Nicolson')
    

    plt.tight_layout()
  
    plt.show()
    plt.subplot(1, 2, 1)
    plt.plot(x,c_EE.T[0])
    plt.plot(x,c_EE.T[30])
    
    plt.subplot(1, 2, 2)
    plt.plot(x,c_CN.T[0])
    plt.plot(x,c_CN.T[30])
  

  return c_EE, c_CN

# %%
c_EE_10,c_CN_10 = changetime (1000,100,0.001)
c_EE_10,c_CN_10 = changetime (1000,1000,0.001)
# Out:
# /tmp/ipykernel_353500/1270183939.py:25: RuntimeWarning: invalid value encountered in add
#   c[:,k] = c[:,k-1] + dt * kappa * M @ c[:,k-1]
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/matplotlib/colors.py:1404: RuntimeWarning: overflow encountered in subtract
#   resdat -= vmin
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/matplotlib/colors.py:1405: RuntimeWarning: overflow encountered in scalar subtract
#   resdat /= (vmax - vmin)
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/matplotlib/colors.py:1405: RuntimeWarning: invalid value encountered in divide
#   resdat /= (vmax - vmin)

# %%
Nts = np.linspace(100,1100,50)
Nxs = np.linspace(100,1100,50)
result  = np.zeros((50,50))

for i,Nt in enumerate(Nts):
    for j,Nx in enumerate(Nxs):
        t = np.linspace(t_start, t_end, int(Nt))  # Create a vector of times
        x = np.linspace(x_start, x_end, int(Nx))  # Create a vector for x

        c_EE = EE(x, t, kappa) # explicit Euler
        mask = np.where(c_EE<0)
        if len(mask[0]) == 0:
            result[i][j] = 1
        else:
            result[i][j] = np.nan
# Out:
# /tmp/ipykernel_353500/1270183939.py:25: RuntimeWarning: invalid value encountered in add
#   c[:,k] = c[:,k-1] + dt * kappa * M @ c[:,k-1]

# %%
xx,yy = np.meshgrid(Nxs,Nts)
mask = np.where(np.isnan(result)==False)
plt.scatter(xx[mask],yy[mask], c=result[mask] )
plt.plot(Nxs,Ntstab)
plt.title('Nts and Nxs for which the Euler method is stable')
plt.xlim(100,1100)
plt.ylim(100,1100)
plt.xlabel('Nx')
plt.ylabel('Nt')
plt.plot()
# Out:
# []

# %% [markdown]
# ----
# The stability field for the Euler method (for 10 seconds) is shown above.
#
#
# Decreasing the time resolution makes the Euler method unstable. An explanation of the stability can be gained from the Euler method being first order with time, wheras the CN method finds the average of derivatives, hence being second-order in time. This means the Euler method reacts much slower to fast diffusion and hence blows up in error by creating larger and larger magnitude parcels of positive and negative concentration.
#
#
# At constant timestep - the Euler method becomes unstable with increasing the number of spatial steps. This is because the gradients are calculated over shorter distances, hence errors from previous steps add up to create a way too large gradient, hence meaning the concentration may overshoot, once again leading to a growing instability.
#
# So in total we care about the ratio of the time-step to the space step size. (In reality the stability condition is $ \frac{\Delta t}{(\Delta x)^2} \leqq 0.5$, but the instability may not occur over the first 10 seconds simulated here). Increasing Kappa makes the instability appear quicker as diffusion is much quicker and hence chances of overshooting and creating negative concentrations increases.
#
#
# ----

# %% [markdown]
# ### 2.2 Accuracy
# <a id='section2pt2'></a>
# Next, we will examine the accuracy of the numerical methods used above. In order to do this, it is useful to compare our numerical solutions with the exact solution to the diffusion equation. Below, write code to plot the exact solution and the numerical solution using explicit Euler and Crank-Nicolson at the final time ($t=10$). Note that you can use the exact solution to the diffusion equation in an unbounded domain in $x$ and keep in mind that the exact solution and numerical solutions will differ for later times when boundary effects are felt.

# %%
# Add code to plot exact and numerical solutions# Add code to plot exact and numerical solutions
# Function to set the initial condition from the exact solution at time t_start

def exact(kappa,x,t_ic):
  c_ic = (4*np.pi*kappa*t_ic)**(-0.5)*np.exp(-x**2 / (4*kappa*t_ic))
  return c_ic

def changetimenoplot (Nt,Nx,kappa):

  t = np.linspace(t_start, t_end, Nt)  # Create a vector of times
  x = np.linspace(x_start, x_end, Nx)  # Create a vector for x

  c_EE = EE(x, t, kappa) # explicit Euler
  c_CN = CN(x, t, kappa) # Crank-Nicolson


  return c_EE, c_CN
def rmse(model,analytical):
  sq_diff = sum((model-analytical)**2)
  avg = sq_diff/len(model)
  return np.sqrt(avg)

# %%
kappa=0.001
x= np.linspace(-1,1,100)
t = np.linspace(0,10,1000)

analytical_solution = exact(kappa,x,20)
c_EE = EE(x, t, kappa) # explicit Euler
c_CN = CN(x, t, kappa) # Crank-Nicolson
# Out:
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_dsolve/linsolve.py:603: SparseEfficiencyWarning: splu converted its input to CSC format
#   return splu(A).solve
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_matfuncs.py:76: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   Ainv = spsolve(A, I)

# %%
plt.plot(x,c_EE.T[-1],label = 'Euler')
plt.plot(x,c_CN.T[-1],label = 'CN')
plt.plot(x,analytical_solution,label = 'Exact Sol')
plt.legend()
plt.ylabel('C')
plt.xlabel('x')
plt.title('Concentration distribution after 10 seconds')
# Out:
# Text(0.5, 1.0, 'Concentration distribution after 10 seconds')

# %%
#plot difference instead, as seems small
plt.plot(x,c_EE.T[-1]-analytical_solution,label = 'Euler')
plt.plot(x,c_CN.T[-1]-analytical_solution, label = 'Crank-Nicolson')

plt.title('Spatial Distribution of Error')
plt.ylabel('Numerical - Analytical ')
plt.xlabel('x')
plt.legend()

# %% [markdown]
# Now, define a measure of the error of each numerical method compared to the exact solution (there is no single correct way to do this). Plot the error of both methods as a function of the grid spacing $\Delta x$. Then, similarly plot the error as a function of the timestep, $\Delta t$.

# %%
errEE=[]
errCN =[]


for Nx in np.linspace(50,450,100):
  #print(Nt)
  c_EE, c_CN = changetimenoplot(1000,int(Nx),0.001)
  x = np.linspace(-1, 1,int(Nx))  # Create a vector for x

  analytic_sol = exact( 0.001,x, 20)
  errEE.append(rmse(analytic_sol,c_EE.T[-1]))

  errCN.append(rmse(analytic_sol,c_CN.T[-1]))

# %%
Nxs
# Out:
# array([2000.        ,  397.59036145,  220.73578595,  152.77777778,
#         116.81415929,   94.55587393,   79.42238267,   68.46473029,
#          60.16408387,   53.65853659,   48.42259721,   44.11764706,
#          40.51565378,   37.45743473,   34.82849604,   32.5443787 ,
#          30.54141601,   28.77070619,   27.19406675,   25.78125   ,
#          24.50798366,   23.35456476,   22.30483271,   21.3454075 ,
#          20.46511628,   19.65455628,   18.90575766,   18.21192053,
#          17.56720788,   16.96658098,   16.40566741,   15.88065448,
#          15.38820238,   14.92537313,   14.4895719 ,   14.07849829,
#          13.69010579,   13.32256762,   12.97424808,   12.64367816,
#          12.32953484,   12.03062341,   11.74586225,   11.47426982,
#          11.21495327,   10.9670987 ,   10.72996261,   10.50286442,
#          10.28517999,   10.07633588,    9.87580428,    9.68309859,
#           9.49776946,    9.3194013 ,    9.14760915,    8.98203593,
# ...

# %%
plt.plot(np.linspace(50,450,100),errEE,label = 'Euler')
plt.plot(np.linspace(50,450,100),errCN, label = 'CN')
plt.xlabel('Nx')

#plt.ylim(0,0.001)
#plt.xlim(0,440)
plt.ylabel('RMSE')
plt.xlabel(r'$Nx$')
plt.legend()

# %%
errEE=[]
errCN =[]
dictEE={}
dictCN={}
x = np.linspace(-1, 1, 100)  # Create a vector for x
analytic_sol = exact( 0.001,x, 20)
for Nt in np.linspace(100,1000,100):
  #print(Nt)
  c_EE, c_CN = changetimenoplot(int(Nt),100,0.001)


  errEE.append(rmse(analytic_sol,c_EE.T[-1]))

  errCN.append(rmse(analytic_sol,c_CN.T[-1]))
# Out:
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_dsolve/linsolve.py:603: SparseEfficiencyWarning: splu converted its input to CSC format
#   return splu(A).solve
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_matfuncs.py:76: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   Ainv = spsolve(A, I)

# %%
plt.plot(np.linspace(100,1000,100),errEE,label = 'Euler')
plt.plot(np.linspace(100,1000,100),errCN,label = 'CN')
plt.xlabel(r'Nt')
plt.ylabel('RMSE')
plt.legend()
plt.plot()
# Out:
# []

# %%
np.shape(c_EE_low)
# Out:
# (100, 100)

# %%
c_EE_low, c_CN = changetimenoplot(int(100),100,0.001)
c_EE_large, c_CN = changetimenoplot(int(300),100,0.001)

# %%
plt.plot(x,c_EE_low.T[-1]-analytic_sol,label = 'Nt=100')
plt.plot(x,c_EE_large.T[-1]-analytic_sol,label = 'Nt=300')
plt.legend()
plt.xlabel('x')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# ----
#
# I used root mean square error (RMSE) as a defention for error here. The RMSE of a numerical method is a function of Nt and Nx, and was calculated comparing to the exact solution at experiment time = 10s, which is 20s in the equation below:
# $$C (x,t)=\left(\frac{1}{4\pi\kappa t}\right)^{1/2}e^{-x^2/(4\kappa t)}$$
#
#
# Taking the root of the mean square error, at a variety of $\Delta x$ and $\Delta t$ obtains the graphs displayed above (the values plotted are all within the region of Euler method stability).
#
# As $\Delta x$  increases (Nx decreases), the resolution decreases, meaning that the RMSE of both methods increases.
#
# A similar trend is expected for time. As the resolution in time increases, the numerical solution is expected to tend to the analyticla solution. However, observationally The Cranck - Nicholson method has some error associated with it, which is independent of \Delta t. With decreasing \Delta t, the Euler method reaches a minimum RMSE at Nt= 150 and then increases towards the RMSE of the Cranck Nicholson method. The minimum may be explained by looking at the distribution of error with space. The shape at small Nt is a reflection of the shape at large Nt, therefore in the moment where it flips a minimum in error is expected.
#
# ----

# %% [markdown]
# Finally, select a given error tolerance and explore whether explicit Euler or Crank-Nicoslon is more efficient (faster) at generating solutions with error less than your error tolerance. Discuss your conclusion and add supporting figures if necessary.

# %%
def returntime (Nt,Nx,kappa,tol):

  t = np.linspace(t_start, t_end, Nt)  # Create a vector of times
  x = np.linspace(x_start, x_end, Nx)  # Create a vector for x
  analytical = exact(kappa,x,20)
  #print(Nx,len(analytical))
  c_EE,t_EE = EE(x, t, kappa,True) # explicit Euler
  c_CN,t_CN = CN(x, t, kappa,True) # Crank-Nicolson
  rmse_EE = rmse(analytical,c_EE.T[-1])
  rmse_CN = rmse(analytical,c_CN.T[-1])
  nprmse = np.array([rmse_EE,rmse_CN])
  nprmse = np.where(nprmse>tol,np.nan,nprmse)
  return nprmse,t_EE,t_CN

# %%
nprmse,t_EE,t_CN = returntime(100,100,0.001,0.0005)
# Out:
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_dsolve/linsolve.py:603: SparseEfficiencyWarning: splu converted its input to CSC format
#   return splu(A).solve
# /home/zhenya/miniconda3/envs/dedalus3/lib/python3.13/site-packages/scipy/sparse/linalg/_matfuncs.py:76: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   Ainv = spsolve(A, I)

# %%
Nts = np.linspace(100,1000,15)
Nxs = np.linspace(100,1000,15)
xx,yy = np.meshgrid(Nts,Nxs)
print(xx,yy)
Ntflat=np.ndarray.flatten(xx)
Nxflat = np.ndarray.flatten(yy)
rmses_EE=[]
rmses_CN=[]
tsEE=[]
tsCN=[]
for i in range (len(Ntflat)):
  nprmse,t_EE,t_CN = returntime(int(Ntflat[i]),int(Nxflat[i]),0.001,0.001)
  rmses_EE.append(nprmse[0])
  rmses_CN.append(nprmse[1])
  tsEE.append(t_EE)
  tsCN.append(t_CN)
# Out:
# [[ 100.          164.28571429  228.57142857  292.85714286  357.14285714
#    421.42857143  485.71428571  550.          614.28571429  678.57142857
#    742.85714286  807.14285714  871.42857143  935.71428571 1000.        ]
#  [ 100.          164.28571429  228.57142857  292.85714286  357.14285714
#    421.42857143  485.71428571  550.          614.28571429  678.57142857
#    742.85714286  807.14285714  871.42857143  935.71428571 1000.        ]
#  [ 100.          164.28571429  228.57142857  292.85714286  357.14285714
#    421.42857143  485.71428571  550.          614.28571429  678.57142857
#    742.85714286  807.14285714  871.42857143  935.71428571 1000.        ]
#  [ 100.          164.28571429  228.57142857  292.85714286  357.14285714
#    421.42857143  485.71428571  550.          614.28571429  678.57142857
#    742.85714286  807.14285714  871.42857143  935.71428571 1000.        ]
#  [ 100.          164.28571429  228.57142857  292.85714286  357.14285714
# ...

# %%
tolerance = 0.0005

nprmses_EE = np.array(rmses_EE)
nptsEE=np.array(tsEE)
nptsEE = np.where(nprmses_EE>tolerance , np.nan, nptsEE)


nprmses_CN = np.array(rmses_CN)
nptsCN=np.array(tsCN)
nptsCN = np.where(nprmses_CN>tolerance , np.nan, nptsCN)

nptsEE = np.where(np.isnan(nprmses_EE)==True,np.nan,nptsEE)
nptsCN = np.where(np.isnan(nprmses_CN)==True,np.nan,nptsCN)

# %%
np.where(np.isnan(nptsCN)==True)
# Out:
# (array([], dtype=int64),)

# %%
plt.scatter(xx,yy,c = nptsEE.reshape([15,15]), s= 15)
plt.colorbar()
plt.show()

plt.scatter(xx,yy,c =nptsCN.reshape([15,15]), s=15 )
plt.colorbar()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_wireframe(xx,yy,nptsEE.reshape([15,15]), rstride=1, cstride=1)


fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_wireframe(xx,yy,nptsCN.reshape([15,15]), rstride=1, cstride=1)

# %%
fig = plt.figure(figsize=(12, 8))  # Increased figure size
fig.tight_layout()
ax = fig.add_subplot(projection='3d')

# Plot the first wireframe
ax.plot_wireframe(xx, yy, nptsEE.reshape([15, 15]), rstride=1, cstride=1, color='blue', label='Time_EE')

# Plot the second wireframe with a different color
ax.plot_wireframe(xx, yy, nptsCN.reshape([15, 15]), rstride=1, cstride=1, color='red', label='Time_CN')

# Adding legend
ax.legend()

# Setting axis labels
ax.set_xlabel('Nt',fontsize = 20)
ax.set_ylabel('Nx',fontsize = 20)
ax.set_zlabel('Compute Time (s)',fontsize = 20)

# Adjust layout to ensure labels are fully visible
plt.subplots_adjust(left=0.05, right=0.85, top=0.9, bottom=0.1)  # Add padding on the right
fig.tight_layout()
ax.view_init(elev=40, azim=290)

# Show the plot
plt.show()

# %% [markdown]
# INSERT DISCUSSION OF ERROR HERE (~1 paragraph).  OPTIONALLY ADD PLOTS BY INSERTING A CODE BLOCK BELOW.

# %% [markdown]
# -----
#
# The error tolerance (in RMSE) was set to 0.0005, slighly larger than the error predicted for the Cranck Nicholson method in the previous section. Computing the concentration over a broad range of Nts and Nxs, it's observed that the Euler method is much faster when it is stable. Therefore, we conclude that it's likely beneficial to use the Euler method when it is stable, but in cases where the Euler method produces nonsense results, the Cranck Nicholson method may be applied later. The inherent difference in compute time between the two methods is the fact that the Euler method is explicit and requires one gradient to be calculated. Wheras the Cranck Nicholson is semi - implicit, and requires calculation of gradients at two points, and then the gradient between the two gradients. Hence the second order in time method requires much more time.
#
# ----

# %% [markdown]
# Now, move to Project1_dedalus.ipynb which will introduce Dedalus and spectral methods.
